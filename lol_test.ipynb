# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time as time
driver = webdriver.Chrome("chromedriver.exe")
a = input("Digite o nome do champion : ")
driver.get("https://www.leagueofgraphs.com/pt/")

driver.find_element_by_xpath(
    '//*[@id="topnavbarform"]/div/div[1]/input').send_keys(a)

driver.find_element_by_xpath(
    '//*[@id="topnavbarform"]/div/div[1]/input').send_keys(Keys.ENTER)

driver.find_element_by_xpath(
    '//*[@id="filters-menu"]/div[2]/div[4]/a').click()

counter = driver.find_element_by_xpath('//*[@id="mainContent"]/div[1]/div[2]/div/div/table/tbody/tr[2]/td[1]/a/div/div[1]/img').get_attribute("alt")
counter2 = driver.find_element_by_xpath('//*[@id="mainContent"]/div[1]/div[2]/div/div/table/tbody/tr[3]/td[1]/a/div/div[1]/img').get_attribute("alt")
counter3 = driver.find_element_by_xpath('//*[@id="mainContent"]/div[1]/div[2]/div/div/table/tbody/tr[4]/td[1]/a/div/div[1]/img').get_attribute("alt")
counter4 = driver.find_element_by_xpath('//*[@id="mainContent"]/div[1]/div[2]/div/div/table/tbody/tr[5]/td[1]/a/div/div[1]/img').get_attribute("alt")
counter5 = driver.find_element_by_xpath('//*[@id="mainContent"]/div[1]/div[2]/div/div/table/tbody/tr[6]/td[1]/a/div/div[1]/img').get_attribute("alt")


c1 = driver.find_element_by_xpath('//*[@id="mainContent"]/div[1]/div[2]/div/div/table/tbody/tr[2]/td[2]/progressbar').get_attribute("data-value")
c2 = driver.find_element_by_xpath('//*[@id="mainContent"]/div[1]/div[2]/div/div/table/tbody/tr[3]/td[2]/progressbar').get_attribute("data-value")
c3 = driver.find_element_by_xpath('//*[@id="mainContent"]/div[1]/div[2]/div/div/table/tbody/tr[4]/td[2]/progressbar').get_attribute("data-value")
c4 = driver.find_element_by_xpath('//*[@id="mainContent"]/div[1]/div[2]/div/div/table/tbody/tr[4]/td[2]/progressbar').get_attribute("data-value")
c5 = driver.find_element_by_xpath('//*[@id="mainContent"]/div[1]/div[2]/div/div/table/tbody/tr[6]/td[2]/progressbar').get_attribute("data-value")
c1 = float(c1)
c2 = float(c2)
c3 = float(c3)
c4 = float(c4)
c5 = float(c5)

g1 = driver.find_element_by_xpath('/html/body/div[2]/div[3]/div[3]/div[1]/div[2]/div[1]/div[1]/div/div/table/tbody/tr[2]/td[2]/progressbar').get_attribute("data-value")
g2 = driver.find_element_by_xpath('//*[@id="mainContent"]/div[1]/div[1]/div/div/table/tbody/tr[3]/td[2]/progressbar').get_attribute("data-value")
g3 = driver.find_element_by_xpath('//*[@id="mainContent"]/div[1]/div[1]/div/div/table/tbody/tr[4]/td[2]/progressbar').get_attribute("data-value")
g4 = driver.find_element_by_xpath('//*[@id="mainContent"]/div[1]/div[1]/div/div/table/tbody/tr[5]/td[2]/progressbar').get_attribute("data-value")
g5 = driver.find_element_by_xpath('//*[@id="mainContent"]/div[1]/div[1]/div/div/table/tbody/tr[6]/td[2]/progressbar').get_attribute("data-value")
g1 = float(g1)
g2 = float(g2)
g3 = float(g3)
g4 = float(g4)
g5 = float(g5)


pick = driver.find_element_by_xpath('//*[@id="mainContent"]/div[1]/div[1]/div/div/table/tbody/tr[2]/td[1]/a/div/div[1]/img').get_attribute("alt")
pick2 = driver.find_element_by_xpath('//*[@id="mainContent"]/div[1]/div[1]/div/div/table/tbody/tr[3]/td[1]/a/div/div[1]/img').get_attribute("alt")
pick3 = driver.find_element_by_xpath('//*[@id="mainContent"]/div[1]/div[1]/div/div/table/tbody/tr[4]/td[1]/a/div/div[1]/img').get_attribute("alt")
pick4 = driver.find_element_by_xpath('//*[@id="mainContent"]/div[1]/div[1]/div/div/table/tbody/tr[5]/td[1]/a/div/div[1]/img').get_attribute("alt")
pick5 = driver.find_element_by_xpath('//*[@id="mainContent"]/div[1]/div[1]/div/div/table/tbody/tr[6]/td[1]/a/div/div[1]/img').get_attribute("alt")
print(f'O {a} tem desvantagem na rota contra:\n. {counter}\n. {counter2}\n. {counter3}\n. {counter4}\n. {counter5}\n')
lista = [counter, counter2, counter3, counter4, counter5]


print(f'O {a} tem vantagem na rota contra:\n. {pick}\n. {pick2}\n. {pick3}\n. {pick4}\n. {pick5}\n')
lista_vant = [pick, pick2, pick3, pick4, pick5]
driver.find_element_by_xpath(
    '/html/body/div[2]/div[3]/div[2]/div[2]/div[7]/a').click()
iten = driver.find_element_by_xpath('//*[@id="mainContent"]/div[1]/div[3]/div/table/tbody/tr[2]/td[1]/img[2]').get_attribute("alt")
iten2 = driver.find_element_by_xpath('//*[@id="mainContent"]/div[1]/div[3]/div/table/tbody/tr[2]/td[1]/img[3]').get_attribute("alt")
iten3 = driver.find_element_by_xpath('//*[@id="mainContent"]/div[1]/div[3]/div/table/tbody/tr[2]/td[1]/img[4]').get_attribute("alt")

iten8 = driver.find_element_by_xpath('/html/body/div[2]/div[3]/div[3]/div[1]/div[2]/div[1]/div[3]/div/table/tbody/tr[2]/td[2]/progressbar/div/div[2]').get_attribute("progressBarTxt")



print(f'Itens core para {a}:\n. {iten}\n. {iten2}\n. {iten3}\n')
driver.quit()

# %%
# Exemplo 1 - Violin Plot

# Carrega o dataset
import pandas as pd

# Cria o Gráfico
import matplotlib.pyplot as plt
import seaborn as sns
a1 = 100

# %%
fatias = [c1*-1, c2*-1, c3*-1,c4*-1,c5*-1]
labels = lista

colors = ['purple', 'lime', 'yellow','blue', 'red']
explode = [0, 0, 0,0,0]
plt.pie(fatias, labels = labels, colors = colors, explode = explode, shadow = True, autopct = "%.2f%%")
plt.title(f'{a} perde a rota contra', fontsize = 20)
plt.axis('off')
#plt.legend()
plt.show()

lista_vant
fatias1 = [g1,g2,g3,g4,g5]
labels1 = lista_vant

colors = ['purple', 'lime', 'yellow','blue', 'red']
explode = [0, 0, 0,0,0]
plt.pie(fatias1, labels = labels1, colors = colors, explode = explode, shadow = True, autopct = "%.2f%%")
plt.title(f'{a} ganhar a rota contra', fontsize = 20)
plt.axis('off')
#plt.legend()
plt.show()

# %%
labels = lista_vant
men_means = fatias


x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='CHANCE DE PERDER')



ax.set_title(f'{a} contra')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
fig.tight_layout()

plt.show()

################
labels = lista
men_means = fatias


x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='CHANCE DE GANHAR')



ax.set_title(f'{a} contra')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt


data = {labels[0]:fatias[0],labels[1]:fatias[1],labels[2]:fatias[2],labels[3]:fatias[3],labels[4]:fatias[4]}


names = list(data.keys())
values = list(data.values())

fig, axs = plt.subplots(1, 3, figsize=(18, 6), sharey=True)
axs[0].bar(names, values)
axs[1].scatter(names, values)
axs[2].plot(names, values)
fig.suptitle(f'{a} tem desvantagem contra')


##############

data1 = {labels1[0]:fatias1[0],labels1[1]:fatias1[1],labels1[2]:fatias1[2],labels1[3]:fatias1[3],labels1[4]:fatias1[4]}

names = list(data1.keys())
values = list(data1.values())

fig, axs = plt.subplots(1, 3, figsize=(18, 6), sharey=True)
axs[0].bar(names, values)
axs[1].scatter(names, values)
axs[2].plot(names, values)
fig.suptitle(f'{a} tem vantagem')
